# %%
import glob
import cv2

file_names = glob.glob("D:\\kitti_dataset\\training\\image_2\\*")
print (len(file_names))
for fn in file_names:
    img = cv2.imread(fn)
    print (img.shape)
# Out:
# 373
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# (375, 1242, 3)
# ...
